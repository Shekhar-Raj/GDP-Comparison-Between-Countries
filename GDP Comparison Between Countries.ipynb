# %%
import os 
import numpy as np
import pandas as pd
import plotly.express as px
import plotly.offline as pyo

# %%
df=pd.read_csv("gdp.txt")
df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %%
final_data=[]
for country_name in df["Country Name"].unique():
    df_pr=df[df['Country Name']==country_name]
    data=df_pr.values
    gdp_change=[0]
    for i in range(1,len(data)):
        prev=data[i-1][3]
        cur=data[i][3]
        gdp_change.append(round(((cur-prev)/prev)*100,2))
    df_pr=df_pr.assign(GDP=gdp_change)
    final_data.append(df_pr)
        
d=pd.concat(final_data,axis=0)
df.head()
# Out:
#   Country Name Country Code  Year         Value
# 0   Arab World          ARB  1968  2.576068e+10
# 1   Arab World          ARB  1969  2.843420e+10
# 2   Arab World          ARB  1970  3.138550e+10
# 3   Arab World          ARB  1971  3.642691e+10
# 4   Arab World          ARB  1972  4.331606e+10

# %% [markdown]
# # GDP of All Countries

# %%
df["Country Name"].unique()
# Out:
# array(['Arab World', 'Caribbean small states',
#        'Central Europe and the Baltics', 'Early-demographic dividend',
#        'East Asia & Pacific',
#        'East Asia & Pacific (excluding high income)',
#        'East Asia & Pacific (IDA & IBRD countries)', 'Euro area',
#        'Europe & Central Asia',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia (IDA & IBRD countries)', 'European Union',
#        'Fragile and conflict affected situations',
#        'Heavily indebted poor countries (HIPC)', 'High income',
#        'IBRD only', 'IDA & IBRD total', 'IDA blend', 'IDA only',
#        'IDA total', 'Late-demographic dividend',
#        'Latin America & Caribbean',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & the Caribbean (IDA & IBRD countries)',
#        'Least developed countries: UN classification',
#        'Low & middle income', 'Low income', 'Lower middle income',
# ...

# %%
fig=px.line(df,x='Year',y="Value",title='GDP Analysis of all countries',color="Country Name")
pyo.plot(fig,filename='GDP.html')
# Out:
# 'GDP.html'

# %% [markdown]
# # GDP Comparison Between India and China.

# %%
c1=df[df["Country Name"]=="China"]
c2=df[df["Country Name"]=="India"]
df_pr=pd.concat((c1,c2),axis=0)
df_pr
# Out:
#      Country Name Country Code  Year         Value
# 4046        China          CHN  1960  5.971647e+10
# 4047        China          CHN  1961  5.005687e+10
# 4048        China          CHN  1962  4.720936e+10
# 4049        China          CHN  1963  5.070680e+10
# 4050        China          CHN  1964  5.970834e+10
# ...           ...          ...   ...           ...
# 6126        India          IND  2012  1.827638e+12
# 6127        India          IND  2013  1.856722e+12
# 6128        India          IND  2014  2.035393e+12
# 6129        India          IND  2015  2.089865e+12
# 6130        India          IND  2016  2.263792e+12
#
# [114 rows x 4 columns]

# %%
fig=px.line(df_pr,x="Year",y="Value",title="GDP Compaarison Between India and China",color="Country Name")
pyo.plot(fig,filename="IND VS CHN.html")
# Out:
# 'IND VS CHN.html'

# %% [markdown]
# # GDP Comparison Between china and World

# %%
c3=df[df["Country Name"]=="China"]
c4=df[df["Country Name"]=="World"]
df_pr=pd.concat([c3,c4],axis=0)
df_pr
# Out:
#      Country Name Country Code  Year         Value
# 4046        China          CHN  1960  5.971647e+10
# 4047        China          CHN  1961  5.005687e+10
# 4048        China          CHN  1962  4.720936e+10
# 4049        China          CHN  1963  5.070680e+10
# 4050        China          CHN  1964  5.970834e+10
# ...           ...          ...   ...           ...
# 2301        World          WLD  2012  7.488995e+13
# 2302        World          WLD  2013  7.699086e+13
# 2303        World          WLD  2014  7.904923e+13
# 2304        World          WLD  2015  7.475775e+13
# 2305        World          WLD  2016  7.584511e+13
#
# [114 rows x 4 columns]

# %%
fig=px.line(df_pr,x="Year",y="Value",title="GDP Comparison of China and World",color="Country Name")
pyo.plot(fig,filename="China Vs World.html")
# Out:
# 'China Vs World.html'

# %%
c5=df[df["Country Name"]=="India"]
c6=df[df["Country Name"]=="Thailand"]
df_po=pd.concat([c5,c6],axis=0)
df_po
# Out:
#       Country Name Country Code  Year         Value
# 6074         India          IND  1960  3.653593e+10
# 6075         India          IND  1961  3.870910e+10
# 6076         India          IND  1962  4.159907e+10
# 6077         India          IND  1963  4.777600e+10
# 6078         India          IND  1964  5.572687e+10
# ...            ...          ...   ...           ...
# 10499     Thailand          THA  2012  3.975600e+11
# 10500     Thailand          THA  2013  4.205287e+11
# 10501     Thailand          THA  2014  4.065216e+11
# 10502     Thailand          THA  2015  3.992345e+11
# 10503     Thailand          THA  2016  4.070261e+11
#
# [114 rows x 4 columns]

# %%
fig3=px.line(df_po,x="Value",y="Year",title="Comparison of India GDP and Thailand GDP",color="Country Name")
pyo.plot(fig3,filename="GDP.html")
# Out:
# 'GDP.html'
